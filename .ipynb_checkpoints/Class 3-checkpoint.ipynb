# %% [markdown]
# # Linked List
#
# There are two varieties of "linked List" when it comes to data structures.
#
# These are:
# 1. Singly linked lists or uni-directional list.
# 2. Doubly linked list or bi-directional lists.

# %%
mylist = []

help(mylist)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
mylist = []
print(mylist)

mylist.append(1)
print(mylist)

mylist.append(2)
print(mylist)
# Out:
# []
# [1]
# [1, 2]

# %%
# From scratch implementation of SinglyLinkedList

class SinglyLinkedList:
    class __Node:
        def __init__(self, datum):
            self.datum = datum
            self.next = None
            
    def __init__(self):
        self.head = None
        self.tail = None
        self.count = 0

    def append(self, value):
        new_node = self.__Node(value)
        self.count += 1
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else: 
            self.tail.next = new_node
            self.tail = new_node

    def insert(self, index, value):
        # this methond insert a new node with "value" Before the given "index"
        pass

    def remove(self, value):
        # this method removes the first instance of "value" and rasies a ValueError if the value is not present in the list
        pass

    def index(self, value):
        # This method returns the position in the list of the given "value" if it is present in the list
        # Otherwise, it raises a ValueError if the value is not present in the list
        pass

    def search(self, index):
        if self.head:
            current = self.head
            count = 0
            while current and count != index:
                if count == index:
                    break
                current = current.next
                count += 1
            return current.datum

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.datum
            current = current.next
            while current:                         # while current is not equal to None
                out += ", %s" % current.datum
                current = current.next
        out += "]"   
        return out

    def __len__(self):
        # this method should return the total number of Nodes in this list.
        return 0

# %%
sll = SinglyLinkedList()

print(sll)

sll.append(1)
print(sll)

sll.append(2)
print(sll)
# Out:
# []
# [1]
# [1, 2]

# %% [markdown]
# # head --> [10 / next value] --> [20 / next value] --> [30 / none or tail]
#           #   index 0                 index 1            index 2
#
#
# state 1: when the list is empty
#     is it different from when teh list is empty and we received a non-zero for the index? A: insert begining at list. it's the head and tail/            recycle appen method
#     what if the list is empty and index is a negative one? none zero? A:
# state 2: when the list contains exactly one Node
#     what happends when index is 0
#     what happens when index is > lenght of the list
#
#
# state 3: when the list contains more than one node
#         what happens when the index would be somewhere between the head and tail of the list?
#         how are we going to insert a new node before the index if it is between the head and tail
